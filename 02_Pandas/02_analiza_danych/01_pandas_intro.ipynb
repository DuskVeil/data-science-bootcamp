# %% [markdown]
# <a href="https://colab.research.google.com/github/DuskVeil/data-science-bootcamp/blob/main/02_Pandas/02_analiza_danych/01_pandas_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * @author: krakowiakpawel9@gmail.com
# * @site: e-smartdata.org

# %% [markdown]
# ### Pandas
# >Strona biblioteki: [https://pandas.pydata.org/](https://pandas.pydata.org/)
# >Dokumentacja: [https://pandas.pydata.org/pandas-docs/stable/](https://pandas.pydata.org/pandas-docs/stable/)
# >
# >Podstawowa biblioteka do analizy danych w języku Python.
# >
# >Aby zainstalować bibliotekę Pandas użyj polecenia poniżej:
# ```
# pip install pandas
# ```
# ### Spis treści:
# 1. [Podstawowe struktury danych: pd.Series](#a1)
# 2. [Podstawowe struktury danych: pd.DataFrame](#a2)
# 3. [Selekcja kolumn](#a3)

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# ### <a name='a1'></a>  Podstawowe struktury danych: pd.Series

# %%
s = pd.Series(data=[3, 2, 4, 6])
s
# Out:
# 0    3
# 1    2
# 2    4
# 3    6
# dtype: int64

# %%
s = pd.Series(data=[3, 2, 4, 6], index=["a", 'b', 'c', 'd'], name='sample')
s
# Out:
# a    3
# b    2
# c    4
# d    6
# Name: sample, dtype: int64

# %%
s = pd.Series(data=[3., 2, 4, 6], index=["a", 'b', 'c', 'd'], name='sample')
s
# Out:
# a    3.0
# b    2.0
# c    4.0
# d    6.0
# Name: sample, dtype: float64

# %%
import numpy as np

np.nan
# Out:
# nan

# %%
s = pd.Series(data=[3., np.nan, 4, 6], index=["a", 'b', 'c', 'd'], name='sample')
s
# Out:
# a    3.0
# b    NaN
# c    4.0
# d    6.0
# Name: sample, dtype: float64

# %%
s = pd.Series(data=[True, False, False])
s
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
s = pd.Series(data=np.arange(10, 20), index=pd.date_range(start='20200101', periods=10))
s
# Out:
# 2020-01-01    10
# 2020-01-02    11
# 2020-01-03    12
# 2020-01-04    13
# 2020-01-05    14
# 2020-01-06    15
# 2020-01-07    16
# 2020-01-08    17
# 2020-01-09    18
# 2020-01-10    19
# Freq: D, dtype: int64

# %%
list(s.index)
# Out:
# [Timestamp('2020-01-01 00:00:00'),
#  Timestamp('2020-01-02 00:00:00'),
#  Timestamp('2020-01-03 00:00:00'),
#  Timestamp('2020-01-04 00:00:00'),
#  Timestamp('2020-01-05 00:00:00'),
#  Timestamp('2020-01-06 00:00:00'),
#  Timestamp('2020-01-07 00:00:00'),
#  Timestamp('2020-01-08 00:00:00'),
#  Timestamp('2020-01-09 00:00:00'),
#  Timestamp('2020-01-10 00:00:00')]

# %%
s = pd.Series(data=['python', 'java', 'sql'], name='language')
s
# Out:
# 0    python
# 1      java
# 2       sql
# Name: language, dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s.values
# Out:
# array(['python', 'java', 'sql'], dtype=object)

# %%
s.dtypes
# Out:
# dtype('O')

# %%
s.shape
# Out:
# (3,)

# %%
price = pd.Series(data={'Apple': 200, 'Cd Project': 60, 'Amazon': 1900, 'KGHM': np.nan})
price
# Out:
# Apple          200.0
# Cd Project      60.0
# Amazon        1900.0
# KGHM             NaN
# dtype: float64

# %%
price['Cd Project']
# Out:
# np.int64(60)

# %%
price[1]
# Out:
# <ipython-input-31-36dbb2ffbeb5>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   price[1]
# np.int64(60)

# %%
price.count()
# Out:
# np.int64(3)

# %%
price.value_counts()
# Out:
# 200.0     1
# 60.0      1
# 1900.0    1
# Name: count, dtype: int64

# %%
price.sum()
# Out:
# np.int64(2160)

# %%
price.min()
# Out:
# 60

# %%
price.max()
# Out:
# 1900

# %%
price.std()
# Out:
# 1024.3046421841502

# %%
price.describe()
# Out:
# count       3.000000
# mean      720.000000
# std      1024.304642
# min        60.000000
# 25%       130.000000
# 50%       200.000000
# 75%      1050.000000
# max      1900.000000
# dtype: float64

# %%
price.describe().T
# Out:
# count       3.000000
# mean      720.000000
# std      1024.304642
# min        60.000000
# 25%       130.000000
# 50%       200.000000
# 75%      1050.000000
# max      1900.000000
# dtype: float64

# %%
price.nlargest(2)
# Out:
# Amazon    1900.0
# Apple      200.0
# dtype: float64

# %%
price.nsmallest(2)
# Out:
# Cd Project     60.0
# Apple         200.0
# dtype: float64

# %%
price.rank()
# Out:
# Apple         2.0
# Cd Project    1.0
# Amazon        3.0
# KGHM          NaN
# dtype: float64

# %%
price.sort_values()
# Out:
# Cd Project      60.0
# Apple          200.0
# Amazon        1900.0
# KGHM             NaN
# dtype: float64

# %%
price.sort_values(ascending=False)
# Out:
# Amazon        1900.0
# Apple          200.0
# Cd Project      60.0
# KGHM             NaN
# dtype: float64

# %%
price_pln = price.apply(lambda x: x * 3.8)

# %%
price
# Out:
# Apple          200.0
# Cd Project      60.0
# Amazon        1900.0
# KGHM             NaN
# dtype: float64

# %% [markdown]
# ### <a name='a2'></a>  Podstawowe struktury danych: pd.DataFrame

# %%
df = pd.DataFrame(data=[12, 12, 32])
df
# Out:
#     0
# 0  12
# 1  12
# 2  32

# %%
df = pd.DataFrame(data=[12, 12, 32], index=['first', 'second', 'trhird'], columns=['col_1'])
df
# Out:
#         col_1
# first      12
# second     12
# trhird     32

# %%
df = pd.DataFrame(data={'WIG20': ['PKN ORLEN', 'PKO BP'],
                        'mWIG40': ['Amica', 'Playway']})
df
# Out:
#        WIG20   mWIG40
# 0  PKN ORLEN    Amica
# 1     PKO BP  Playway

# %%
df = pd.DataFrame(data=[[10, 12, 32], [23, 12, 10]], index=['first', 'second'], columns=['col_1', 'col_2', 'col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      10     12     32
# second     23     12     10

# %%
df.columns
# Out:
# Index(['col_1', 'col_2', 'col_3'], dtype='object')

# %%
df.index
# Out:
# Index(['first', 'second'], dtype='object')

# %%
df.values
# Out:
# array([[10, 12, 32],
#        [23, 12, 10]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, first to second
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_1   2 non-null      int64
#  1   col_2   2 non-null      int64
#  2   col_3   2 non-null      int64
# dtypes: int64(3)
# memory usage: 172.0+ bytes

# %%
df.describe()
# Out:
#            col_1  col_2      col_3
# count   2.000000    2.0   2.000000
# mean   16.500000   12.0  21.000000
# std     9.192388    0.0  15.556349
# min    10.000000   12.0  10.000000
# 25%    13.250000   12.0  15.500000
# 50%    16.500000   12.0  21.000000
# 75%    19.750000   12.0  26.500000
# max    23.000000   12.0  32.000000

# %%
df.describe().T
# Out:
#        count  mean        std   min    25%   50%    75%   max
# col_1    2.0  16.5   9.192388  10.0  13.25  16.5  19.75  23.0
# col_2    2.0  12.0   0.000000  12.0  12.00  12.0  12.00  12.0
# col_3    2.0  21.0  15.556349  10.0  15.50  21.0  26.50  32.0

# %% [markdown]
# ### <a name='a3'> </a> Selekcja kolumn

# %%
df
# Out:
#         col_1  col_2  col_3
# first      10     12     32
# second     23     12     10

# %%
df['col_1']
# Out:
# first     10
# second    23
# Name: col_1, dtype: int64

# %%
type(df['col_1'])
# Out:
# pandas.core.series.Series

# %%
df[['col_1']]
# Out:
#         col_1
# first      10
# second     23

# %%
type(df[['col_1']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns = ['a', 'b', 'c']
df
# Out:
#          a   b   c
# first   10  12  32
# second  23  12  10

# %%
df.a
# Out:
# first     10
# second    23
# Name: a, dtype: int64

# %%
df.b
# Out:
# first     12
# second    12
# Name: b, dtype: int64

# %%
df = pd.DataFrame(data=[[10, 12, 32], [23, 12, 10]], index=['first', 'second'], columns=['col_1', 'col_2', 'col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      10     12     32
# second     23     12     10

# %%
df.loc['first']
# Out:
# col_1    10
# col_2    12
# col_3    32
# Name: first, dtype: int64

# %%
df.loc['first', 'col_2']
# Out:
# np.int64(12)

# %%
df.loc[:, 'col_2']
# Out:
# first     12
# second    12
# Name: col_2, dtype: int64

# %%
df.loc['second']
# Out:
# col_1    23
# col_2    12
# col_3    10
# Name: second, dtype: int64

# %%
df.iloc[0, 1]
# Out:
# np.int64(12)
